# %% [markdown]
# # Fall 2024 Data Science Track: Week 5 - Unsupervised Learning

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need: `matplotlib`, `networkx`, `numpy`, and `pandas`―and also `ast.literal_eval` to correctly deserialize two columns in the `rules.tsv.xz` file.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Don’t worry about this. This is needed to interpret the Python code that is embedded in the data set. You only need it literally in the very next code cell and nowhere else. 
from ast import literal_eval

# The rest is just the stuff from the lecture.
from matplotlib import pyplot as plt
import networkx as nx
import numpy as np
import pandas as pd

# %% [markdown]
# # Instacart Association Rules

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the Instacart association rules data set, mined from the [Instacart Market Basket Analysis data set](https://www.kaggle.com/c/instacart-market-basket-analysis/data) on Kaggle. [The script](https://github.com/LiKenun/shopping-assistant/blob/main/api/preprocess_instacart_market_basket_analysis_data.py) that does it and the instructions to run it can be found in my [Shopping Assistant Project](https://github.com/LiKenun/shopping-assistant) repository.

# %% [markdown]
# ## Load the Data
#
# This code has already been pre-written, simply because there are a few quirks which require converters to ensure the correct deserialization of some columns.

# %%
rules_data_path = 'data/rules.tsv.xz'                       # You do not need to decompress this yourself. Pandas understands how to read compressed data.

df_rules = pd.read_csv(rules_data_path,
                       sep='\t',
                       quoting=3,                           # This disables interpretation of quotes by Pandas itself, because both single and double quotes will be resolved by literal_eval.
                       converters={
                           'consequent_item': literal_eval,
                           'antecedent_items': literal_eval # This reads something like ["Grandma's 8\" Chip Cookies", '6" Apple Pie'] into a list, so you will get a column where each individual cell is a list.
                       },
                       low_memory=True)                     # For Chris
# Out:
# <unknown>:1: SyntaxWarning: invalid escape sequence '\G'

# %% [markdown]
# But just *how* many rules were just loaded‽

# %%
# Show the list of column names and the number of rules.
print('The list of columns are: ', df_rules.columns.tolist())
print('The number of rules are: ', df_rules.shape[0])
# Out:
# The list of columns are:  ['consequent_item', 'transaction_count', 'item_set_count', 'antecedent_count', 'consequent_count', 'antecedent_items']
# The number of rules are:  1048575

# %% [markdown]
# ## Metrics
#
# Compute the support, confidence, and lift of each rule.
#
# * The rule’s *support* tells you how frequently the set of items appears in the dataset. It’s important to prune infrequent sets from further consideration.
#     * The simple definition: $$P(A \cap B)$$
#     * `= item_set_count / transaction_count`
# * The rule’s *confidence* tells you how often a the rule is true. Divide the support for the set of items by the support for just the antecedents. Rules which are not true very often are also pruned.
#     * The simple definition: $$\frac{P(A \cap B)}{P(A)}$$
#     * `= item_set_count / transaction_count / (antecedent_count / transaction_count)`
#     * `= item_set_count / antecedent_count`
# * The rule’s *lift* tells you how much more likely the consequent is, given the antecedents, compared to its baseline probability. Divide the support for the set of items by both the support of the antecedents and consequent. Equivalently, divide the confidence by the support of the consequent.
#     * The simple definition: $$\frac{P(A \cap B)}{P(A) \cdot P(B)}$$
#     * `= item_set_count / transaction_count / (antecedent_count / transaction_count * (consequent_count / transaction_count))`
#     * `= item_set_count / antecedent_count / (consequent_count / transaction_count)`
#     * `= item_set_count * transaction_count / (antecedent_count * consequent_count)`

# %%
# Add new columns support, confidence, and lift to df_rules. And show the first 50 rules.
item_set_count = df_rules['item_set_count']
transaction_count = df_rules['transaction_count']
antecedent_count = df_rules['antecedent_count']
consequent_count = df_rules['consequent_count']

df_rules['support'] = item_set_count / transaction_count
df_rules['confidence'] = item_set_count / antecedent_count
df_rules['lift'] =item_set_count * transaction_count / (antecedent_count * consequent_count)

df_rules.head(50)
# Out:
#                                       consequent_item  transaction_count  \
# 0   Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 1   Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 2    Total 0% with Honey Nonfat Greek Strained Yogurt            3346083
# 3                           Total 0% Raspberry Yogurt            3346083
# 4                                 Pineapple Yogurt 2%            3346083
# 5                          Fat Free Strawberry Yogurt            3346083
# 6                           Fat Free Blueberry Yogurt            3346083
# 7   Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 8   Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 9   Total 2% Greek Strained Yogurt with Cherry 5.3 oz            3346083
# 10  Total 2% All Natural Greek Strained Yogurt wit...            3346083
# 11                          Total 0% Raspberry Yogurt            3346083
# 12                                Pineapple Yogurt 2%            3346083
# 13                         Fat Free Strawberry Yogurt            3346083
# 14                                  Blackberry Yogurt            3346083
# 15  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 16  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 17   Total 0% with Honey Nonfat Greek Strained Yogurt            3346083
# 18                          Total 0% Raspberry Yogurt            3346083
# 19                                Pineapple Yogurt 2%            3346083
# 20                         Fat Free Strawberry Yogurt            3346083
# 21                          Fat Free Blueberry Yogurt            3346083
# 22  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 23  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 24  Total 2% Greek Strained Yogurt with Cherry 5.3 oz            3346083
# 25  Total 2% All Natural Greek Strained Yogurt wit...            3346083
# 26                          Total 0% Raspberry Yogurt            3346083
# 27                                Pineapple Yogurt 2%            3346083
# 28                         Fat Free Strawberry Yogurt            3346083
# 29                                  Blackberry Yogurt            3346083
# 30  Total 2% with Strawberry Lowfat Greek Strained...            3346083
# 31  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 32   Total 2% Lowfat Greek Strained Yogurt with Peach            3346083
# 33  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 34  Total 2% Greek Strained Yogurt with Cherry 5.3 oz            3346083
# 35  Total 2% All Natural Greek Strained Yogurt wit...            3346083
# 36                          Total 0% Raspberry Yogurt            3346083
# 37                         Fat Free Strawberry Yogurt            3346083
# 38                                  Blackberry Yogurt            3346083
# 39  Total 2% with Strawberry Lowfat Greek Strained...            3346083
# 40  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 41   Total 2% Lowfat Greek Strained Yogurt with Peach            3346083
# 42  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 43  Total 2% Greek Strained Yogurt with Cherry 5.3 oz            3346083
# 44  Total 2% All Natural Greek Strained Yogurt wit...            3346083
# 45                          Total 0% Raspberry Yogurt            3346083
# 46                         Fat Free Strawberry Yogurt            3346083
# 47                                  Blackberry Yogurt            3346083
# 48  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 49  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
#
#     item_set_count  antecedent_count  consequent_count  \
# 0              101               123               128
# 1              101               128               123
# 2              101               123               128
# 3              101               123               128
# 4              101               128               123
# 5              101               123               128
# 6              101               128               123
# 7              101               147               117
# 8              101               147               117
# 9              101               117               147
# 10             101               117               147
# 11             101               147               117
# 12             101               147               117
# 13             101               117               147
# 14             101               117               147
# 15             101               119               145
# 16             101               145               119
# 17             101               119               145
# 18             101               145               119
# 19             101               145               119
# 20             101               119               145
# 21             101               145               119
# 22             101               132               133
# 23             101               132               133
# 24             101               133               132
# 25             101               132               133
# 26             101               133               132
# 27             101               133               132
# 28             101               132               133
# 29             101               133               132
# 30             103               129               139
# 31             103               139               129
# 32             103               139               129
# 33             103               139               129
# 34             103               129               139
# 35             103               139               129
# 36             103               139               129
# 37             103               129               139
# 38             103               129               139
# 39             103               144               125
# 40             103               144               125
# 41             103               125               144
# 42             103               144               125
# 43             103               125               144
# 44             103               144               125
# 45             103               144               125
# 46             103               125               144
# 47             103               125               144
# 48             102               123               145
# 49             102               145               123
#
#                                      antecedent_items   support  confidence  \
# 0   [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.821138
# 1   [Fat Free Strawberry Yogurt, Total 0% Raspberr...  0.000030    0.789062
# 2   [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.821138
# 3   [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.821138
# 4   [Fat Free Strawberry Yogurt, Total 0% Raspberr...  0.000030    0.789062
# 5   [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.821138
# 6   [Fat Free Strawberry Yogurt, Total 0% Raspberr...  0.000030    0.789062
# 7   [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000030    0.687075
# 8   [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000030    0.687075
# 9   [Pineapple Yogurt 2%, Total 0% Raspberry Yogur...  0.000030    0.863248
# 10  [Pineapple Yogurt 2%, Total 0% Raspberry Yogur...  0.000030    0.863248
# 11  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000030    0.687075
# 12  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000030    0.687075
# 13  [Pineapple Yogurt 2%, Total 0% Raspberry Yogur...  0.000030    0.863248
# 14  [Pineapple Yogurt 2%, Total 0% Raspberry Yogur...  0.000030    0.863248
# 15  [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.848739
# 16  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000030    0.696552
# 17  [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.848739
# 18  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000030    0.696552
# 19  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000030    0.696552
# 20  [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.848739
# 21  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000030    0.696552
# 22  [Blackberry Yogurt, Pineapple Yogurt 2%, Total...  0.000030    0.765152
# 23  [Blackberry Yogurt, Pineapple Yogurt 2%, Total...  0.000030    0.765152
# 24  [Fat Free Strawberry Yogurt, Total 2% All Natu...  0.000030    0.759398
# 25  [Blackberry Yogurt, Pineapple Yogurt 2%, Total...  0.000030    0.765152
# 26  [Fat Free Strawberry Yogurt, Total 2% All Natu...  0.000030    0.759398
# 27  [Fat Free Strawberry Yogurt, Total 2% All Natu...  0.000030    0.759398
# 28  [Blackberry Yogurt, Pineapple Yogurt 2%, Total...  0.000030    0.765152
# 29  [Fat Free Strawberry Yogurt, Total 2% All Natu...  0.000030    0.759398
# 30  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.798450
# 31  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.741007
# 32  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.741007
# 33  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.741007
# 34  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.798450
# 35  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.741007
# 36  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.741007
# 37  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.798450
# 38  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.798450
# 39  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.715278
# 40  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.715278
# 41  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.824000
# 42  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.715278
# 43  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.824000
# 44  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.715278
# 45  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.715278
# 46  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.824000
# 47  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.824000
# 48  [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.829268
# 49  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000030    0.703448
#
#             lift
# 0   21465.598514
# 1   21465.598514
# 2   21465.598514
# 3   21465.598514
# 4   21465.598514
# 5   21465.598514
# 6   21465.598514
# 7   19649.653061
# 8   19649.653061
# 9   19649.653061
# 10  19649.653061
# 11  19649.653061
# 12  19649.653061
# 13  19649.653061
# 14  19649.653061
# 15  19585.881368
# 16  19585.881368
# 17  19585.881368
# 18  19585.881368
# 19  19585.881368
# 20  19585.881368
# 21  19585.881368
# 22  19250.078776
# 23  19250.078776
# 24  19250.078776
# 25  19250.078776
# 26  19250.078776
# 27  19250.078776
# 28  19250.078776
# 29  19250.078776
# 30  19220.709888
# 31  19220.709888
# 32  19220.709888
# 33  19220.709888
# 34  19220.709888
# 35  19220.709888
# 36  19220.709888
# 37  19220.709888
# 38  19220.709888
# 39  19147.030500
# 40  19147.030500
# 41  19147.030500
# 42  19147.030500
# 43  19147.030500
# 44  19147.030500
# 45  19147.030500
# 46  19147.030500
# 47  19147.030500
# 48  19136.555425
# 49  19136.555425

# %% [markdown]
# The yogurts have got some insane lift (*over 9,000*). Why do you think that might be?

# %% [markdown]
# Yogurt can be an item that is bought alongside other specific items (like granola, fruits, or breakfast foods), which causes the lift to be very high.

# %%
# Query the rule set if you have to to find out more.
yogurt_rules = df_rules[df_rules['consequent_item'].apply(lambda x: 'yogurt' in x or 'Yogurt' in x)]
yogurt_rules.sort_values(by='lift', ascending=False).head(50)
# Out:
#                                       consequent_item  transaction_count  \
# 0   Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 2    Total 0% with Honey Nonfat Greek Strained Yogurt            3346083
# 3                           Total 0% Raspberry Yogurt            3346083
# 4                                 Pineapple Yogurt 2%            3346083
# 5                          Fat Free Strawberry Yogurt            3346083
# 6                           Fat Free Blueberry Yogurt            3346083
# 1   Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 11                          Total 0% Raspberry Yogurt            3346083
# 14                                  Blackberry Yogurt            3346083
# 13                         Fat Free Strawberry Yogurt            3346083
# 12                                Pineapple Yogurt 2%            3346083
# 9   Total 2% Greek Strained Yogurt with Cherry 5.3 oz            3346083
# 10  Total 2% All Natural Greek Strained Yogurt wit...            3346083
# 8   Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 7   Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 19                                Pineapple Yogurt 2%            3346083
# 21                          Fat Free Blueberry Yogurt            3346083
# 20                         Fat Free Strawberry Yogurt            3346083
# 17   Total 0% with Honey Nonfat Greek Strained Yogurt            3346083
# 18                          Total 0% Raspberry Yogurt            3346083
# 16  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 15  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 22  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 23  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 24  Total 2% Greek Strained Yogurt with Cherry 5.3 oz            3346083
# 25  Total 2% All Natural Greek Strained Yogurt wit...            3346083
# 26                          Total 0% Raspberry Yogurt            3346083
# 27                                Pineapple Yogurt 2%            3346083
# 28                         Fat Free Strawberry Yogurt            3346083
# 29                                  Blackberry Yogurt            3346083
# 34  Total 2% Greek Strained Yogurt with Cherry 5.3 oz            3346083
# 38                                  Blackberry Yogurt            3346083
# 37                         Fat Free Strawberry Yogurt            3346083
# 35  Total 2% All Natural Greek Strained Yogurt wit...            3346083
# 36                          Total 0% Raspberry Yogurt            3346083
# 33  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 32   Total 2% Lowfat Greek Strained Yogurt with Peach            3346083
# 31  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 30  Total 2% with Strawberry Lowfat Greek Strained...            3346083
# 43  Total 2% Greek Strained Yogurt with Cherry 5.3 oz            3346083
# 47                                  Blackberry Yogurt            3346083
# 45                          Total 0% Raspberry Yogurt            3346083
# 44  Total 2% All Natural Greek Strained Yogurt wit...            3346083
# 46                         Fat Free Strawberry Yogurt            3346083
# 42  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 41   Total 2% Lowfat Greek Strained Yogurt with Peach            3346083
# 40  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 39  Total 2% with Strawberry Lowfat Greek Strained...            3346083
# 48  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 49  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
#
#     item_set_count  antecedent_count  consequent_count  \
# 0              101               123               128
# 2              101               123               128
# 3              101               123               128
# 4              101               128               123
# 5              101               123               128
# 6              101               128               123
# 1              101               128               123
# 11             101               147               117
# 14             101               117               147
# 13             101               117               147
# 12             101               147               117
# 9              101               117               147
# 10             101               117               147
# 8              101               147               117
# 7              101               147               117
# 19             101               145               119
# 21             101               145               119
# 20             101               119               145
# 17             101               119               145
# 18             101               145               119
# 16             101               145               119
# 15             101               119               145
# 22             101               132               133
# 23             101               132               133
# 24             101               133               132
# 25             101               132               133
# 26             101               133               132
# 27             101               133               132
# 28             101               132               133
# 29             101               133               132
# 34             103               129               139
# 38             103               129               139
# 37             103               129               139
# 35             103               139               129
# 36             103               139               129
# 33             103               139               129
# 32             103               139               129
# 31             103               139               129
# 30             103               129               139
# 43             103               125               144
# 47             103               125               144
# 45             103               144               125
# 44             103               144               125
# 46             103               125               144
# 42             103               144               125
# 41             103               125               144
# 40             103               144               125
# 39             103               144               125
# 48             102               123               145
# 49             102               145               123
#
#                                      antecedent_items   support  confidence  \
# 0   [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.821138
# 2   [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.821138
# 3   [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.821138
# 4   [Fat Free Strawberry Yogurt, Total 0% Raspberr...  0.000030    0.789062
# 5   [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.821138
# 6   [Fat Free Strawberry Yogurt, Total 0% Raspberr...  0.000030    0.789062
# 1   [Fat Free Strawberry Yogurt, Total 0% Raspberr...  0.000030    0.789062
# 11  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000030    0.687075
# 14  [Pineapple Yogurt 2%, Total 0% Raspberry Yogur...  0.000030    0.863248
# 13  [Pineapple Yogurt 2%, Total 0% Raspberry Yogur...  0.000030    0.863248
# 12  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000030    0.687075
# 9   [Pineapple Yogurt 2%, Total 0% Raspberry Yogur...  0.000030    0.863248
# 10  [Pineapple Yogurt 2%, Total 0% Raspberry Yogur...  0.000030    0.863248
# 8   [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000030    0.687075
# 7   [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000030    0.687075
# 19  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000030    0.696552
# 21  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000030    0.696552
# 20  [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.848739
# 17  [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.848739
# 18  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000030    0.696552
# 16  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000030    0.696552
# 15  [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.848739
# 22  [Blackberry Yogurt, Pineapple Yogurt 2%, Total...  0.000030    0.765152
# 23  [Blackberry Yogurt, Pineapple Yogurt 2%, Total...  0.000030    0.765152
# 24  [Fat Free Strawberry Yogurt, Total 2% All Natu...  0.000030    0.759398
# 25  [Blackberry Yogurt, Pineapple Yogurt 2%, Total...  0.000030    0.765152
# 26  [Fat Free Strawberry Yogurt, Total 2% All Natu...  0.000030    0.759398
# 27  [Fat Free Strawberry Yogurt, Total 2% All Natu...  0.000030    0.759398
# 28  [Blackberry Yogurt, Pineapple Yogurt 2%, Total...  0.000030    0.765152
# 29  [Fat Free Strawberry Yogurt, Total 2% All Natu...  0.000030    0.759398
# 34  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.798450
# 38  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.798450
# 37  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.798450
# 35  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.741007
# 36  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.741007
# 33  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.741007
# 32  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.741007
# 31  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.741007
# 30  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.798450
# 43  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.824000
# 47  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.824000
# 45  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.715278
# 44  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.715278
# 46  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.824000
# 42  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.715278
# 41  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031    0.824000
# 40  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.715278
# 39  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031    0.715278
# 48  [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030    0.829268
# 49  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000030    0.703448
#
#             lift
# 0   21465.598514
# 2   21465.598514
# 3   21465.598514
# 4   21465.598514
# 5   21465.598514
# 6   21465.598514
# 1   21465.598514
# 11  19649.653061
# 14  19649.653061
# 13  19649.653061
# 12  19649.653061
# 9   19649.653061
# 10  19649.653061
# 8   19649.653061
# 7   19649.653061
# 19  19585.881368
# 21  19585.881368
# 20  19585.881368
# 17  19585.881368
# 18  19585.881368
# 16  19585.881368
# 15  19585.881368
# 22  19250.078776
# 23  19250.078776
# 24  19250.078776
# 25  19250.078776
# 26  19250.078776
# 27  19250.078776
# 28  19250.078776
# 29  19250.078776
# 34  19220.709888
# 38  19220.709888
# 37  19220.709888
# 35  19220.709888
# 36  19220.709888
# 33  19220.709888
# 32  19220.709888
# 31  19220.709888
# 30  19220.709888
# 43  19147.030500
# 47  19147.030500
# 45  19147.030500
# 44  19147.030500
# 46  19147.030500
# 42  19147.030500
# 41  19147.030500
# 40  19147.030500
# 39  19147.030500
# 48  19136.555425
# 49  19136.555425

# %% [markdown]
# ## Network Visualization for Consequents with Single Antecedents
#
# Let’s now visualize a small subset of 1,000,000+ rules. First, filter the rule set for the following to whittle it down to something more manageable:
#
# 1. The rule must have exactly `1` antecedent item. (There should be 38,684 such rules.)
# 2. The lift must be between `5` and `20`. (There should be 1,596 such rules, including the prior criterion.)
# 3. Either the antecedent or consequent of the rule must contain `'Hummus'`, but not both. (This should get you down to 26 rules.)
#     * Convert the antecedents `list`-typed column to a `str`-typed column (`antecedent_item`) since there will only be a single antecedent in the subset.
#     * Replace any item containing `'Hummus'` to just `'Hummus'`. This will make the visualization more readable later.
#
# Hint: your code may run more efficiently if you re-order certain processing steps.
#
# Assign the subset to `df_rules_subset`.

# %%
# Define df_rules_subset.
antecedent_condition = df_rules['antecedent_items'].apply(len)==1
df_rules_subset = df_rules[antecedent_condition]

lift_condition = (df_rules_subset['lift'] >= 5) & (df_rules_subset['lift'] <= 20)
df_rules_subset = df_rules_subset[lift_condition]

#Convert list to string, then replace any item containing 'Hummus' to just 'Hummus'
df_rules_subset['antecedent_item'] = df_rules_subset['antecedent_items'].str.join('').apply(lambda x: 'Hummus' if 'Hummus' in x else x)
df_rules_subset['consequent_item'] = df_rules_subset['consequent_item'].apply(lambda x: 'Hummus' if 'Hummus' in x else x)
con_hummus_condition = df_rules_subset['consequent_item'].apply(lambda x: 'Hummus' in x)
ant_hummus_condition = df_rules_subset['antecedent_item'].apply(lambda x: 'Hummus' in x)
df_rules_subset = df_rules_subset[(ant_hummus_condition & ~con_hummus_condition) | 
                                  (con_hummus_condition & ~ant_hummus_condition)]

df_rules_subset.reset_index(drop=True)
# Out:
#                                       consequent_item  transaction_count  \
# 0   Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 1                                         Clementines            3346083
# 2                                              Hummus            3346083
# 3                                              Hummus            3346083
# 4                                              Hummus            3346083
# 5                                              Hummus            3346083
# 6                                Organic Baby Carrots            3346083
# 7                                              Hummus            3346083
# 8                                              Hummus            3346083
# 9                                              Hummus            3346083
# 10                                             Hummus            3346083
# 11                                             Hummus            3346083
# 12                                             Hummus            3346083
# 13                                             Hummus            3346083
# 14                                             Hummus            3346083
# 15                                             Hummus            3346083
# 16                               Organic Baby Carrots            3346083
# 17                                             Hummus            3346083
# 18                                             Hummus            3346083
# 19                         Organic Small Bunch Celery            3346083
# 20                                             Hummus            3346083
# 21                                             Hummus            3346083
# 22                                             Hummus            3346083
# 23                                             Hummus            3346083
# 24                               Organic Baby Carrots            3346083
#
#     item_set_count  antecedent_count  consequent_count  \
# 0              100               887             21405
# 1              174              1334             32194
# 2              345              1656             74172
# 3              293              1434             74172
# 4              331              1655             74172
# 5             3119             17333             74172
# 6              258              1334             80493
# 7              151               933             74172
# 8              311              1929             74172
# 9              512              3333             74172
# 10             168              1208             74172
# 11             117               875             74172
# 12            1544             11702             74172
# 13             166              1287             74172
# 14             244              1973             74172
# 15             104               843             74172
# 16             122               918             80493
# 17             250              2066             74172
# 18             221              1887             74172
# 19             109               985             70714
# 20             126              1086             74172
# 21             287              2479             74172
# 22             257              2223             74172
# 23             111               962             74172
# 24             235              1945             80493
#
#                                      antecedent_items   support  confidence  \
# 0              [Roasted Red Pepper Hummus With Chips]  0.000030    0.112740
# 1                            [Organic Classic Hummus]  0.000052    0.130435
# 2                          [Organic White Pita Bread]  0.000103    0.208333
# 3                          [Organic Whole Wheat Pita]  0.000088    0.204324
# 4                       [Mini Whole Wheat Pita Bread]  0.000099    0.200000
# 5                               [Sea Salt Pita Chips]  0.000932    0.179946
# 6                            [Organic Classic Hummus]  0.000077    0.193403
# 7                 [Lentil Chips, Himalayan Pink Salt]  0.000045    0.161844
# 8                      [Garbanzo Beans No Salt Added]  0.000093    0.161223
# 9                 [Organic Whole Peeled Baby Carrots]  0.000153    0.153615
# 10                      [Baba Ghannouge Eggplant Dip]  0.000050    0.139073
# 11  [Sonoma Organic Wraps Multigrain Tortillas Wit...  0.000035    0.133714
# 12                          [Pita Chips Simply Naked]  0.000461    0.131943
# 13                          [Honey Whole Wheat Bread]  0.000050    0.128982
# 14                                       [White Pita]  0.000073    0.123670
# 15                              [Organic Wraps Wheat]  0.000031    0.123369
# 16                                  [Kalamata Hummus]  0.000036    0.132898
# 17             [Rice Thins Brown Rice Snack Crackers]  0.000075    0.121007
# 18                                           [Dolmas]  0.000066    0.117117
# 19                            [Organic Garlic Hummus]  0.000033    0.110660
# 20                                      [Wasabi Peas]  0.000038    0.116022
# 21            [Organic Unsweetened Soy Milk Beverage]  0.000086    0.115772
# 22                    [Traditional Basil Pesto Sauce]  0.000077    0.115610
# 23                          [Teriyaki Veggie Burgers]  0.000033    0.115385
# 24                       [Organic Traditional Hummus]  0.000070    0.120823
#
#          lift                                    antecedent_item
# 0   17.623731                                             Hummus
# 1   13.556738                                             Hummus
# 2    9.398434                           Organic White Pita Bread
# 3    9.217543                           Organic Whole Wheat Pita
# 4    9.022496                        Mini Whole Wheat Pita Bread
# 5    8.117800                                Sea Salt Pita Chips
# 6    8.039749                                             Hummus
# 7    7.301163                  Lentil Chips, Himalayan Pink Salt
# 8    7.273189                       Garbanzo Beans No Salt Added
# 9    6.929970                  Organic Whole Peeled Baby Carrots
# 10   6.273921                        Baba Ghannouge Eggplant Dip
# 11   6.032183  Sonoma Organic Wraps Multigrain Tortillas With...
# 12   5.952288                            Pita Chips Simply Naked
# 13   5.818704                            Honey Whole Wheat Bread
# 14   5.579040                                         White Pita
# 15   5.565478                                Organic Wraps Wheat
# 16   5.524535                                             Hummus
# 17   5.458916               Rice Thins Brown Rice Snack Crackers
# 18   5.283444                                             Dolmas
# 19   5.236264                                             Hummus
# 20   5.234045                                        Wasabi Peas
# 21   5.222784              Organic Unsweetened Soy Milk Beverage
# 22   5.215433                      Traditional Basil Pesto Sauce
# 23   5.205286                            Teriyaki Veggie Burgers
# 24   5.022580                                             Hummus

# %% [markdown]
# Build a network `graph_rules_subset` from the association rules subset.

# %%
# Define graph_rules_subset, add the graph’s edges, and plot it. You may need a large figure size, smaller node size, and smaller font size.
from_nodes = df_rules_subset['antecedent_item']
to_nodes = df_rules_subset['consequent_item']

graph_rules_subset = nx.MultiDiGraph()
graph_rules_subset.add_edges_from(
    zip(from_nodes, to_nodes)
)

# Then render the graph.
plt.figure(1, figsize=(9, 9))
pos = nx.shell_layout(graph_rules_subset)

nx.draw(
    graph_rules_subset, pos, with_labels=True, 
    node_size=800, font_size=6, font_color='black', 
    node_color='lightblue', edge_color='gray'
)

# %% [markdown]
# What can you tell about people who buy hummus?

# %% [markdown]
# People who buy hummus often buy it with other healthy foods that go well with hummus. Hummus is commonly associated with healthy or snack items like vegetables, pita bread, or other dips.

# %% [markdown]
# ## Make a Prediction
#
# Given that the basket of items contains the following items, use the full set of association rules to predict the next 20 most likely items (consequents) that the person will add to the basket in descending order of lift:
#
# * `'Orange Bell Pepper'`
# * `'Organic Red Bell Pepper'`
#
# Hint: a single item in the basket may be a better predictor of some consequents than both items considered together. You must consider both or either, but not neither.

# %%
basket = {'Orange Bell Pepper', 'Organic Red Bell Pepper'}

pepper_filter = df_rules['antecedent_items'].apply(lambda x: any(item in x for item in basket))
df_rules[pepper_filter]\
        .sort_values(by='lift', ascending=False)\
        .head(20).reset_index(drop=True)
# Out:
#                                       consequent_item  transaction_count  \
# 0       Icelandic Style Skyr Blueberry Non-fat Yogurt            3346083
# 1       Icelandic Style Skyr Blueberry Non-fat Yogurt            3346083
# 2            Nonfat Icelandic Style Strawberry Yogurt            3346083
# 3                            Non Fat Raspberry Yogurt            3346083
# 4       Icelandic Style Skyr Blueberry Non-fat Yogurt            3346083
# 5       Icelandic Style Skyr Blueberry Non-fat Yogurt            3346083
# 6                            Non Fat Raspberry Yogurt            3346083
# 7       Icelandic Style Skyr Blueberry Non-fat Yogurt            3346083
# 8            Nonfat Icelandic Style Strawberry Yogurt            3346083
# 9       Icelandic Style Skyr Blueberry Non-fat Yogurt            3346083
# 10                         Vanilla Skyr Nonfat Yogurt            3346083
# 11                        Organic Frozen Mango Chunks            3346083
# 12                         Vanilla Skyr Nonfat Yogurt            3346083
# 13                         Organic Orange Bell Pepper            3346083
# 14                           Non Fat Raspberry Yogurt            3346083
# 15                             Organic Sliced Peaches            3346083
# 16  Total 2% with Strawberry Lowfat Greek Strained...            3346083
# 17                                Organic Bell Pepper            3346083
# 18                                Organic Bell Pepper            3346083
# 19                                 Yellow Bell Pepper            3346083
#
#     item_set_count  antecedent_count  consequent_count  \
# 0              100               209             19962
# 1              132               311             19962
# 2              100               441             11025
# 3              184               529             16953
# 4              184               494             19962
# 5              167               471             19962
# 6              132               441             16953
# 7              101               291             19962
# 8              101               529             11025
# 9              133               392             19962
# 10             167               529             18899
# 11             109               612             10938
# 12             133               441             18899
# 13             145               834             11005
# 14             126               471             16953
# 15             109               676             10300
# 16             235               502             30866
# 17             114               324             24331
# 18             145               420             24331
# 19             109               295             26625
#
#                                      antecedent_items   support  confidence  \
# 0   [Nonfat Icelandic Style Strawberry Yogurt, Ora...  0.000030    0.478469
# 1      [Non Fat Raspberry Yogurt, Orange Bell Pepper]  0.000039    0.424437
# 2   [Icelandic Style Skyr Blueberry Non-fat Yogurt...  0.000030    0.226757
# 3   [Icelandic Style Skyr Blueberry Non-fat Yogurt...  0.000055    0.347826
# 4   [Non Fat Raspberry Yogurt, Organic Red Bell Pe...  0.000055    0.372470
# 5   [Organic Red Bell Pepper, Vanilla Skyr Nonfat ...  0.000050    0.354565
# 6   [Icelandic Style Skyr Blueberry Non-fat Yogurt...  0.000039    0.299320
# 7   [Nonfat Icelandic Style Strawberry Yogurt, Org...  0.000030    0.347079
# 8   [Icelandic Style Skyr Blueberry Non-fat Yogurt...  0.000030    0.190926
# 9    [Orange Bell Pepper, Vanilla Skyr Nonfat Yogurt]  0.000040    0.339286
# 10  [Icelandic Style Skyr Blueberry Non-fat Yogurt...  0.000050    0.315690
# 11  [Organic Red Bell Pepper, Organic Sliced Peaches]  0.000033    0.178105
# 12  [Icelandic Style Skyr Blueberry Non-fat Yogurt...  0.000040    0.301587
# 13  [Organic Bell Pepper, Organic Raspberries, Org...  0.000043    0.173861
# 14  [Organic Red Bell Pepper, Vanilla Skyr Nonfat ...  0.000038    0.267516
# 15  [Organic Frozen Mango Chunks, Organic Red Bell...  0.000033    0.161243
# 16  [Organic Red Bell Pepper, Total 2% Lowfat Gree...  0.000070    0.468127
# 17  [Organic Cucumber, Organic Orange Bell Pepper,...  0.000034    0.351852
# 18  [Organic Orange Bell Pepper, Organic Raspberri...  0.000043    0.345238
# 19     [Grade A Large Brown Eggs, Orange Bell Pepper]  0.000033    0.369492
#
#          lift
# 0   80.202217
# 1   71.145298
# 2   68.820769
# 3   68.651858
# 4   62.434341
# 5   59.433078
# 6   59.077960
# 7   58.178302
# 8   57.946047
# 9   56.871965
# 10  55.893163
# 11  54.484612
# 12  53.396272
# 13  52.862612
# 14  52.800713
# 15  52.381664
# 16  50.748184
# 17  48.387880
# 18  47.478333
# 19  46.435655

# %% [markdown]
# ## Bonus: Other Interesting Findings
#
# Find and share something else interesting about these association rules. It can be a graph, table, or some other format that illustrates your point.
